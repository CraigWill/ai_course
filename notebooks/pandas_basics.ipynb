# %% [markdown]
# # Pandas 基础演示

# %%
import pandas as pd
df = pd.DataFrame({
    'group': ['A','A','B','B','B'],
    'value': [1,2,3,4,5]
})
print(df.info())
print(df.groupby('group')['value'].mean())
