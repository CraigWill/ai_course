# %% [markdown]
# # 预处理演示

# %%
from src.data import preprocess_breast_cancer
splits = preprocess_breast_cancer(seed=42)
print('train:', splits.X_train.shape, 'val:', splits.X_val.shape, 'test:', splits.X_test.shape)
