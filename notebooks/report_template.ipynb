# %% [markdown]
# # 技术报告模板\n\n数据描述、方法、实验设置、指标表与图表、结论与局限

# %%
import os, pandas as pd\ncsv_path = os.path.join('experiments', 'metrics.csv')\nif os.path.exists(csv_path):\n    display(pd.read_csv(csv_path).tail())\nelse:\n    print('尚未产生 metrics.csv，先运行训练脚本。')
