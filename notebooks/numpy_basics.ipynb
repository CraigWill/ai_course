# %% [markdown]
# # NumPy 基础演示

# %%
import numpy as np
a = np.arange(12)
b = a.reshape(3, 4)
c = b + np.array([1, 2, 3, 4])
print('a shape:', a.shape)
print('b shape:', b.shape)
print('c first row:', c[0])
